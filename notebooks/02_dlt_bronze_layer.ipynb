# %%
import dlt

# Bronze: raw ingestion of three delta streams

@dlt.table(
    name="01_bronze.bridge_temperature",
    comment="Raw temperature readings"
)
def bronze_bridge_temperature():
    return (
        spark.readStream
             .format("delta")
             .load("/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_temperature")
    )

@dlt.table(
    name="01_bronze.bridge_vibration",
    comment="Raw vibration readings"
)
def bronze_bridge_vibration():
    return (
        spark.readStream
             .format("delta")
             .load("/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_vibration")
    )

@dlt.table(
    name="01_bronze.bridge_tilt",
    comment="Raw tilt-angle readings"
)
def bronze_bridge_tilt():
    return (
        spark.readStream
             .format("delta")
             .load("/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_tilt")
    )
# Out:
#     <html>
#       <div style="font-size:18px">
#         The Delta Live Tables (DLT) module is not supported on this cluster.
#         You should either <a href="?o=7405615130056849#joblist/pipelines/create?initialSource=%2FUsers%2Fdjjohnson%40compliance314.onmicrosoft.com%2F02_dlt_bronze_layer&redirectNotebookId=1245046335570169">create a new pipeline</a> or use an existing pipeline to run DLT code.
#       </div>
#     </html>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File <command-6914108983967127>, line 1
# ----> 1 import dlt
#       3 # Bronze: raw ingestion of three delta streams
#       5 @dlt.table(name="01_bronze.bridge_temperature", comment="Raw temperature readings")
#       6 def bronze_bridge_temperature():
#
# ModuleNotFoundError: No module named 'dlt'

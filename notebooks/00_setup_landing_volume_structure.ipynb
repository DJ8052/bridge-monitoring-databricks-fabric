# %%
base_path = "/Volumes/bridge_monitoring/00_landing/landing_stream"

dbutils.fs.mkdirs(f"{base_path}/bridge_temperature")
dbutils.fs.mkdirs(f"{base_path}/bridge_tilt")
dbutils.fs.mkdirs(f"{base_path}/bridge_vibration")
# Out:
# True

# %%
dbutils.fs.ls("/Volumes/bridge_monitoring/00_landing/landing_stream")
# Out:
# [FileInfo(path='dbfs:/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_temperature/', name='bridge_temperature/', size=0, modificationTime=1767278910000),
#  FileInfo(path='dbfs:/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_tilt/', name='bridge_tilt/', size=0, modificationTime=1767278911000),
#  FileInfo(path='dbfs:/Volumes/bridge_monitoring/00_landing/landing_stream/bridge_vibration/', name='bridge_vibration/', size=0, modificationTime=1767278911000)]
